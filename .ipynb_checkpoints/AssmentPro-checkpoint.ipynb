# %% [markdown]
# # Assessment Test

# %% [markdown]
# First of all we start by downloading the data:

# %%
import pandas as pd
import numpy as np
import struct
pd.options.display.max_rows = 10

# %%
dtng = pd.read_stata('NGPR7AFL.DTA')

# %%
dtng.head()
# Out:
#            hhid  hvidx hv000  hv001  hv002 hv003  hv004    hv005  hv006  \
# 0         1   1      1   NG7      1      1     1      1  1368354      9
# 1         1   1      2   NG7      1      1     1      1  1368354      9
# 2         1   1      3   NG7      1      1     1      1  1368354      9
# 3         1   1      4   NG7      1      1     1      1  1368354      9
# 4         1   1      5   NG7      1      1     1      1  1368354      9
#
#    hv007  ...  idxdis  hdis1                 hdis2  hdis3  \
# 0   2018  ...       1    yes       some difficulty     no
# 1   2018  ...       2     no  no difficulty seeing     no
# 2   2018  ...       3     no  no difficulty seeing     no
# 3   2018  ...       4     no  no difficulty seeing     no
# 4   2018  ...       5    NaN                   NaN    NaN
#
#                    hdis4                        hdis5  \
# 0  no difficulty hearing  no difficulty communicating
# 1  no difficulty hearing  no difficulty communicating
# 2  no difficulty hearing  no difficulty communicating
# 3  no difficulty hearing  no difficulty communicating
# 4                    NaN                          NaN
#
#                                      hdis6                              hdis7  \
# 0                          some difficulty                    some difficulty
# 1  no difficulty remembering/concentrating  no difficulty walking or climbing
# 2  no difficulty remembering/concentrating  no difficulty walking or climbing
# 3  no difficulty remembering/concentrating  no difficulty walking or climbing
# 4                                      NaN                                NaN
#
#                                hdis8            hdis9
# 0                    some difficulty  some difficulty
# 1  no difficulty washing or dressing    no difficulty
# 2  no difficulty washing or dressing    no difficulty
# 3  no difficulty washing or dressing    no difficulty
# 4                                NaN              NaN
#
# [5 rows x 357 columns]

# %%
dtng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 188010 entries, 0 to 188009
# Columns: 357 entries, hhid to hdis9
# dtypes: category(280), float64(37), int16(11), int32(5), int8(19), object(5)
# memory usage: 131.0+ MB

# %%
dtng.describe()
# Out:
#                hvidx          hv001          hv002          hv004  \
# count  188010.000000  188010.000000  188010.000000  188010.000000
# mean        3.909196     644.667193      30.704228     644.667193
# std         3.008769     378.258235      24.882841     378.258235
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000     339.000000      13.000000     339.000000
# 50%         3.000000     607.000000      26.000000     607.000000
# 75%         5.000000     935.000000      41.000000     935.000000
# max        37.000000    1400.000000     294.000000    1400.000000
#
#               hv005          hv006     hv007          hv008         hv008a  \
# count  1.880100e+05  188010.000000  188010.0  188010.000000  188010.000000
# mean   1.008755e+06      10.113318    2018.0    1426.113318   43392.114356
# std    6.705459e+05       1.208128       0.0       1.208128      35.514281
# min    1.058190e+05       8.000000    2018.0    1424.000000   43327.000000
# 25%    6.130340e+05       9.000000    2018.0    1425.000000   43361.000000
# 50%    8.798980e+05      10.000000    2018.0    1426.000000   43390.000000
# 75%    1.243910e+06      11.000000    2018.0    1427.000000   43426.000000
# max    1.365677e+07      12.000000    2018.0    1428.000000   43465.000000
#
#                hv009  ...          hmlb          hmlc          hmld  hmle  \
# count  188010.000000  ...  64301.000000  34412.000000  10267.000000   0.0
# mean        6.818393  ...      4.559494      5.702313      6.110841   NaN
# std         3.973084  ...      2.878795      2.775441      2.767218   NaN
# min         1.000000  ...      1.000000      1.000000      1.000000   NaN
# 25%         4.000000  ...      2.000000      4.000000      4.000000   NaN
# 50%         6.000000  ...      4.000000      5.000000      6.000000   NaN
# 75%         8.000000  ...      6.000000      7.000000      7.000000   NaN
# max        37.000000  ...     30.000000     31.000000     24.000000   NaN
#
#               hmhidx       hml14     hml15        hml16a         hml36  \
# count  188010.000000  653.000000  7.000000  11590.000000  11577.000000
# mean        3.909196    3.160796  3.428571     32.151251   1946.357951
# std         3.008769    1.347638  0.786796     15.619140   1062.221806
# min         1.000000    2.000000  3.000000      6.000000    108.000000
# 25%         2.000000    2.000000  3.000000     18.000000   1110.000000
# 50%         3.000000    3.000000  3.000000     32.000000   1910.000000
# 75%         5.000000    4.000000  3.500000     46.000000   2809.000000
# max        37.000000    7.000000  5.000000     59.000000   3711.000000
#
#               idxdis
# count  188010.000000
# mean        3.909196
# std         3.008769
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max        37.000000
#
# [8 rows x 72 columns]

# %%
# !head -n 357 NGPR7AFL.MAP
# Out:
#                                                    NGPR7AFL
#                                                 NGPR7AFL_DICT
#
#                                         NGPR7AFL.DCF
#                                     Last Modified:  11/4/2019  7:32:00 PM
#
# --------------------------------------------------------------------------------------------------------------
# Level Name                    Level Label                                                  Type            Rec
#   Record Name                   Record Label                                              Value  Req  Max  Len
# --------------------------------------------------------------------------------------------------------------
# HOUSEHOLD                     HOUSEHOLD
#   RECORD1                       RECORD1                                                          Yes    1  728
# Level: HOUSEHOLD                                       Record: RECORD1
# --------------------------------------------------------------------------------------------------------------
#                                                                                  Data Item            Dec Zero
# Item Name              Item Label                                     Start  Len Type Type  Occ  Dec Char Fill
# --------------------------------------------------------------------------------------------------------------
# HHID              (id) Case Identification                                1   12   AN    I    1    0   No   No
# HVIDX             (id) Line number                                       13    2    N    I    1    0   No   No
#                                1:90
#                          (record type)                                    0    0   AN    I    1    0   No   No
# HV000                  Country code and phase                            15    3   AN    I    1    0   No   No
# HV001                  Cluster number                                    18    6    N    I    1    0   No   No
# HV002                  Household number                                  24    6    N    I    1    0   No   No
# HV003                  Respondent's line number (answering Household q   30    3    N    I    1    0   No   No
#                                0      Incomplete household
#                                1:999
# HV004                  Ultimate area unit                                33    4    N    I    1    0   No   No
# HV005                  Household sample weight (6 decimals)              37    8    N    I    1    0   No   No
# HV006                  Month of interview                                45    2    N    I    1    0   No   No
#                                1:12
# HV007                  Year of interview                                 47    4    N    I    1    0   No   No
#                                2015:2025
# HV008                  Date of interview (CMC)                           51    4    N    I    1    0   No   No
# HV008A                 Date of interview Century Day Code (CDC)          55    5    N    I    1    0   No   No
# HV009                  Number of household members                       60    2    N    I    1    0   No   No
#                                0:90
# HV010                  Number of eligible women in household             62    2    N    I    1    0   No   No
#                                0:20
# HV011                  Number of eligible men in household               64    2    N    I    1    0   No   No
#                                0:20
# HV012                  Number of de jure members                         66    2    N    I    1    0   No   No
#                                0:90
# HV013                  Number of de facto members                        68    2    N    I    1    0   No   No
#                                0:90
# HV014                  Number of children 5 and under (de jure)          70    2    N    I    1    0   No   No
#                                0:20
# HV015                  Result of household interview                     72    1    N    I    1    0   No   No
#                                1  Completed
#                                2  No Household member/no competent member at home
#                                3  Entire Household absent for extended period of time
#                                4  Postponed
#                                5  Refused
#                                6  Dwelling vacant or address not a dwelling
#                                7  Dwelling destroyed
#                                8  Dwelling not found
#                                9  Other
# HV016                  Day of interview                                  73    2    N    I    1    0   No   No
#                                1:31
# HV017                  Number of visits                                  75    1    N    I    1    0   No   No
#                                1:8
#                            (m) 9    Missing
# HV018                  Interviewer identification                        76    5    N    I    1    0   No   No
# HV019                  NA - Keyer identification                         81    3    N    I    1    0   No   No
# HV020                  Ever-married sample                               84    1    N    I    1    0   No   No
#                                0  All woman sample
#                                1  Ever married sample
# HV021                  Primary sampling unit                             85    4    N    I    1    0   No   No
# HV022                  Sample strata for sampling errors                 89    4    N    I    1    0   No   No
#                                1   NC Benue Urban
#                                2   NC Benue Rural
#                                3   NC FCT Abuja Urban
#                                4   NC FCT Abuja Rural
#                                5   NC Kogi Urban
#                                6   NC Kogi Rural
#                                7   NC Kwara Urban
#                                8   NC Kwara Rural
#                                9   NC Nasarawa Urban
#                                10  NC Nasarawa Rural
#                                11  NC Niger Urban
#                                12  NC Niger Rural
#                                13  NC Plateau Urban
#                                14  NC Plateau Rural
#                                15  NE Adamawa Urban
#                                16  NE Adamawa Rural
#                                17  NE Bauchi Urban
#                                18  NE Bauchi Rural
#                                19  NE Borno Urban
#                                20  NE Borno Rural
#                                21  NE Gombe Urban
#                                22  NE Gombe Rural
#                                23  NE Taraba Urban
#                                24  NE Taraba Rural
#                                25  NE Yobe Urban
#                                26  NE Yobe Rural
#                                27  NW Jigawa Urban
#                                28  NW Jigawa Rural
#                                29  NW Kaduna Urban
#                                30  NW Kaduna Rural
#                                31  NW Kano Urban
#                                32  NW Kano Rural
#                                33  NW Katsina Urban
#                                34  NW Katsina Rural
#                                35  NW Kebbi Urban
#                                36  NW Kebbi Rural
#                                37  NW Sokoto Urban
#                                38  NW Sokoto Rural
#                                39  NW Zamfara Urban
#                                40  NW Zamfara Rural
#                                41  SE Abia Urban
#                                42  SE Abia Rural
#                                43  SE Anambra Urban
#                                44  SE Anambra Rural
#                                45  SE Ebonyi Urban
#                                46  SE Ebonyi Rural
#                                47  SE Enugu Urban
#                                48  SE Enugu Rural
#                                49  SE Imo Urban
#                                50  SE Imo Rural
#                                51  SS Akwa Ibom Urban
#                                52  SS Akwa Ibom Rural
#                                53  SS Bayelsa Urban
#                                54  SS Bayelsa Rural
#                                55  SS Cross River Urban
#                                56  SS Cross River Rural
#                                57  SS Delta Urban
#                                58  SS Delta Rural
#                                59  SS Edo Urban
#                                60  SS Edo Rural
#                                61  SS Rivers Urban
#                                62  SS Rivers Rural
#                                63  SW Ekiti Urban
#                                64  SW Ekiti Rural
#                                65  SW Lagos Urban
#                                66  SW Lagos Rural
#                                67  SW Ogun Urban
#                                68  SW Ogun Rural
#                                69  SW Ondo Urban
#                                70  SW Ondo Rural
#                                71  SW Osun Urban
#                                72  SW Osun Rural
#                                73  SW Oyo Urban
#                                74  SW Oyo Rural
# HV023                  Stratification used in sample design              93    2    N    I    1    0   No   No
#                                1   NC Benue Urban
#                                2   NC Benue Rural
#                                3   NC FCT Abuja Urban
#                                4   NC FCT Abuja Rural
#                                5   NC Kogi Urban
#                                6   NC Kogi Rural
#                                7   NC Kwara Urban
#                                8   NC Kwara Rural
#                                9   NC Nasarawa Urban
#                                10  NC Nasarawa Rural
#                                11  NC Niger Urban
#                                12  NC Niger Rural
#                                13  NC Plateau Urban
#                                14  NC Plateau Rural
#                                15  NE Adamawa Urban
#                                16  NE Adamawa Rural
#                                17  NE Bauchi Urban
#                                18  NE Bauchi Rural
#                                19  NE Borno Urban
#                                20  NE Borno Rural
#                                21  NE Gombe Urban
#                                22  NE Gombe Rural
#                                23  NE Taraba Urban
#                                24  NE Taraba Rural
#                                25  NE Yobe Urban
#                                26  NE Yobe Rural
#                                27  NW Jigawa Urban
#                                28  NW Jigawa Rural
#                                29  NW Kaduna Urban
#                                30  NW Kaduna Rural
#                                31  NW Kano Urban
#                                32  NW Kano Rural
#                                33  NW Katsina Urban
#                                34  NW Katsina Rural
#                                35  NW Kebbi Urban
#                                36  NW Kebbi Rural
#                                37  NW Sokoto Urban
#                                38  NW Sokoto Rural
#                                39  NW Zamfara Urban
#                                40  NW Zamfara Rural
#                                41  SE Abia Urban
#                                42  SE Abia Rural
#                                43  SE Anambra Urban
#                                44  SE Anambra Rural
#                                45  SE Ebonyi Urban
#                                46  SE Ebonyi Rural
#                                47  SE Enugu Urban
#                                48  SE Enugu Rural
#                                49  SE Imo Urban
#                                50  SE Imo Rural
#                                51  SS Akwa Ibom Urban
#                                52  SS Akwa Ibom Rural
#                                53  SS Bayelsa Urban
#                                54  SS Bayelsa Rural
#                                55  SS Cross River Urban
#                                56  SS Cross River Rural
#                                57  SS Delta Urban
#                                58  SS Delta Rural
#                                59  SS Edo Urban
#                                60  SS Edo Rural
#                                61  SS Rivers Urban
#                                62  SS Rivers Rural
#                                63  SW Ekiti Urban
#                                64  SW Ekiti Rural
#                                65  SW Lagos Urban
#                                66  SW Lagos Rural
#                                67  SW Ogun Urban
#                                68  SW Ogun Rural
#                                69  SW Ondo Urban
#                                70  SW Ondo Rural
#                                71  SW Osun Urban
#                                72  SW Osun Rural
#                                73  SW Oyo Urban
#                                74  SW Oyo Rural
# HV024                  Region                                            95    2    N    I    1    0   No   No
#                                1  North Central
#                                2  North East
#                                3  North West
#                                4  South East
#                                5  South South
#                                6  South West
# HV025                  Type of place of residence                        97    1    N    I    1    0   No   No
#                                1  Urban
#                                2  Rural
# HV026                  NA - Place of residence                           98    1    N    I    1    0   No   No
#                                0  Capital, large city
#                                1  Small city
#                                2  Town
#                                3  Countryside
#                            (m) 9  Missing
# HV027                  Household selected for male interview             99    1    N    I    1    0   No   No
#                                0  Not selected
#                                1  Men's survey
#                                2  Husband's survey
# HV028                  Household weight for male subsample (6 decimals  100    8    N    I    1    0   No   No
# HV030                  Field supervisor                                 108    5    N    I    1    0   No   No
# HV031                  NA - Field editor                                113    5    N    I    1    0   No   No
# HV032                  NA - Office editor                               118    3    N    I    1    0   No   No
# HV035                  Number of eligible children for height and weig  121    2    N    I    1    0   No   No
#                                0:20
# HV040                  Cluster altitude in meters                       123    4    N    I    1    0   No   No
#                            (m) 9999  Missing
# HV041                  Total adults measured                            127    2    N    I    1    0   No   No
#                                0:20
# HV042                  Household selected for hemoglobin                129    1    N    I    1    0   No   No
#                                0  Not selected
#                                1  Selected
# HV044                  Household selected for Domestic Violence module  130    1    N    I    1    0   No   No
#                                0  Household not selected
#                                1  Household selected
#                           (na)    Not applicable
# HV045A                 Language of questionnaire                        131    3    N    I    1    0   No   No
#                                1  English
#                                2  Hausa
#                                3  Yoruba
#                                4  Igbo
# HV045B                 Language of interview                            134    3    N    I    1    0   No   No
#                                1  English
#                                2  Hausa
#                                3  Yoruba
#                                4  Igbo
# HV045C                 Native language of respondent                    137    3    N    I    1    0   No   No
#                                1  English
#                                2  Hausa
#                                3  Yoruba
#                                4  Igbo
#                                9  Other
# HV046                  Translator used                                  140    1    N    I    1    0   No   No
#                                0  No
#                                1  Yes
# HV801                  Time interview started (hhmm - 24 hour clock)    141    4    N    I    1    0   No   No
#                                340:2330
#                            (m) 9999      Missing
# HV802                  Time interview ended (hhmm - 24 hour clock)      145    4    N    I    1    0   No   No
#                                357:2330
#                            (m) 9999      Missing
# HV803                  Length of interview in minutes                   149    2    N    I    1    0   No   No
#                                0:94
#                                95    95+
#                                96    2+ visits
#                                97    Inconsistent
#                            (m) 99    Missing
# HV804                  Number of visits for biomarker                   151    1    N    I    1    0   No   No
#                                1:8
#                            (m) 9    Missing
# HV807D                 Day of biomarker visit                           152    2    N    I    1    0   No   No
#                                1:31
# HV807M                 Month of biomarker visit                         154    2    N    I    1    0   No   No
#                                1:12
# HV807Y                 Year of biomarker visit                          156    4    N    I    1    0   No   No
#                                2015:2025
# HV807C                 Date of biomarker (CMC)                          160    4    N    I    1    0   No   No
# HV807A                 Date of biomarker Century Day Code (CDC)         164    5    N    I    1    0   No   No
# HV201                  Source of drinking water                         169    2    N    I    1    0   No   No
#                                10  PIPED WATER
#                                11  Piped into dwelling
#                                12  Piped to yard/plot
#                                13  Piped to neighbor
#                                14  Public tap/standpipe
#                                20  TUBE WELL WATER
#                                21  Tube well or borehole
#                                30  DUG WELL (OPEN/PROTECTED)
#                                31  Protected well
#                                32  Unprotected well
#                                40  SURFACE FROM SPRING
#                                41  Protected spring
#                                42  Unprotected spring
#                                43  River/dam/lake/ponds/stream/canal/irrigation channel
#                                51  Rainwater
#                                61  Tanker truck
#                                62  Cart with small tank
#                                71  Bottled water
#                                92  Sachet water
#                                96  Other
#                            (m) 99  Missing
# HV202                  Source of non-drinking water                     171    2    N    I    1    0   No   No
#                                10  PIPED WATER
#                                11  Piped into dwelling
#                                12  Piped to yard/plot
#                                13  Piped to neighbor
#                                14  Public tap/standpipe
#                                20  TUBE WELL WATER
#                                21  Tube well or borehole
#                                30  DUG WELL (OPEN/PROTECTED)
#                                31  Protected well
#                                32  Unprotected well
#                                40  SURFACE FROM SPRING
#                                41  Protected spring
#                                42  Unprotected spring
#                                43  River/dam/lake/ponds/stream/canal/irrigation channel
#                                51  Rainwater
#                                61  Tanker truck
#                                62  Cart with small tank
#                                71  Bottled water
#                                92  Sachet water
#                                96  Other
#                            (m) 99  Missing
# HV201A                 Water not available for at least a day last two  173    1    N    I    1    0   No   No
#                                0  No, not interrupted for a full day
#                                1  Yes, interrupted for a full day or more
#                                8  Don't know
#                            (m) 9  Missing
#                           (na)    Not applicable
# HV204                  Time to get to water source (minutes)            174    3    N    I    1    0   No   No
#                                0:900
#                                996    On premises
#                                998    Don't know
#                            (m) 999    Missing
#                           (na)        Not applicable
# HV205                  Type of toilet facility                          177    2    N    I    1    0   No   No
#                                10  FLUSH TOILET
#                                11  Flush to piped sewer system
#                                12  Flush to septic tank

# %%
import geopandas as gpd
gdf = gpd.read_file("shapefile/gadm36_NGA_1.shp")

# %%
gdf[:]
# Out:
#    GID_0   NAME_0     GID_1     NAME_1 VARNAME_1  NL_NAME_1 TYPE_1 ENGTYPE_1  \
# 0    NGA  Nigeria   NGA.1_1       Abia       NaN        NaN  State     State
# 1    NGA  Nigeria   NGA.2_1    Adamawa       NaN        NaN  State     State
# 2    NGA  Nigeria   NGA.3_1  Akwa Ibom       NaN        NaN  State     State
# 3    NGA  Nigeria   NGA.4_1    Anambra       NaN        NaN  State     State
# 4    NGA  Nigeria   NGA.5_1     Bauchi       NaN        NaN  State     State
# ..   ...      ...       ...        ...       ...        ...    ...       ...
# 32   NGA  Nigeria  NGA.33_1     Rivers       NaN        NaN  State     State
# 33   NGA  Nigeria  NGA.34_1     Sokoto       NaN        NaN  State     State
# 34   NGA  Nigeria  NGA.35_1     Taraba       NaN        NaN  State     State
# 35   NGA  Nigeria  NGA.36_1       Yobe       NaN        NaN  State     State
# 36   NGA  Nigeria  NGA.37_1    Zamfara       NaN        NaN  State     State
#
#     CC_1 HASC_1                                           geometry
# 0    NaN  NG.AB  POLYGON ((7.48998 4.85506, 7.49438 4.84743, 7....
# 1    NaN  NG.AD  POLYGON ((12.01237 7.50763, 12.00726 7.50804, ...
# 2    NaN  NG.AK  MULTIPOLYGON (((7.55570 4.50408, 7.55597 4.504...
# 3    NaN  NG.AN  POLYGON ((7.25012 5.92631, 7.24832 5.92668, 7....
# 4    NaN  NG.BA  POLYGON ((11.01984 9.70526, 11.02580 9.69224, ...
# ..   ...    ...                                                ...
# 32   NaN  NG.RI  MULTIPOLYGON (((6.69722 4.45042, 6.69736 4.450...
# 33   NaN  NG.SO  POLYGON ((4.59020 11.82821, 4.59251 11.84297, ...
# 34   NaN  NG.TA  POLYGON ((10.15367 7.03837, 10.15335 7.03845, ...
# 35   NaN  NG.YO  POLYGON ((11.58203 10.65642, 11.58155 10.66303...
# 36   NaN  NG.ZA  POLYGON ((7.09464 12.38045, 7.09280 12.37099, ...
#
# [37 rows x 11 columns]

# %%
# !head -n 357 NGPR7AFL.DO
# Out:
# infix using "C:\COUNTRIES\NG7A\NGPR7AFL.dct"
#
# label variable hhid     "Case Identification"
# label variable hvidx    "Line number"
# label variable hv000    "Country code and phase"
# label variable hv001    "Cluster number"
# label variable hv002    "Household number"
# label variable hv003    "Respondent's line number (answering Household questionnaire)"
# label variable hv004    "Ultimate area unit"
# label variable hv005    "Household sample weight (6 decimals)"
# label variable hv006    "Month of interview"
# label variable hv007    "Year of interview"
# label variable hv008    "Date of interview (CMC)"
# label variable hv008a   "Date of interview Century Day Code (CDC)"
# label variable hv009    "Number of household members"
# label variable hv010    "Number of eligible women in household"
# label variable hv011    "Number of eligible men in household"
# label variable hv012    "Number of de jure members"
# label variable hv013    "Number of de facto members"
# label variable hv014    "Number of children 5 and under (de jure)"
# label variable hv015    "Result of household interview"
# label variable hv016    "Day of interview"
# label variable hv017    "Number of visits"
# label variable hv018    "Interviewer identification"
# label variable hv019    "NA - Keyer identification"
# label variable hv020    "Ever-married sample"
# label variable hv021    "Primary sampling unit"
# label variable hv022    "Sample strata for sampling errors"
# label variable hv023    "Stratification used in sample design"
# label variable hv024    "Region"
# label variable hv025    "Type of place of residence"
# label variable hv026    "NA - Place of residence"
# label variable hv027    "Household selected for male interview"
# label variable hv028    "Household weight for male subsample (6 decimals)"
# label variable hv030    "Field supervisor"
# label variable hv031    "NA - Field editor"
# label variable hv032    "NA - Office editor"
# label variable hv035    "Number of eligible children for height and weight"
# label variable hv040    "Cluster altitude in meters"
# label variable hv041    "Total adults measured"
# label variable hv042    "Household selected for hemoglobin"
# label variable hv044    "Household selected for Domestic Violence module"
# label variable hv045a   "Language of questionnaire"
# label variable hv045b   "Language of interview"
# label variable hv045c   "Native language of respondent"
# label variable hv046    "Translator used"
# label variable hv801    "Time interview started (hhmm - 24 hour clock)"
# label variable hv802    "Time interview ended (hhmm - 24 hour clock)"
# label variable hv803    "Length of interview in minutes"
# label variable hv804    "Number of visits for biomarker"
# label variable hv807d   "Day of biomarker visit"
# label variable hv807m   "Month of biomarker visit"
# label variable hv807y   "Year of biomarker visit"
# label variable hv807c   "Date of biomarker (CMC)"
# label variable hv807a   "Date of biomarker Century Day Code (CDC)"
# label variable hv201    "Source of drinking water"
# label variable hv202    "Source of non-drinking water"
# label variable hv201a   "Water not available for at least a day last two weeks"
# label variable hv204    "Time to get to water source (minutes)"
# label variable hv205    "Type of toilet facility"
# label variable hv206    "Has electricity"
# label variable hv207    "Has radio"
# label variable hv208    "Has television"
# label variable hv209    "Has refrigerator"
# label variable hv210    "Has bicycle"
# label variable hv211    "Has motorcycle/scooter"
# label variable hv212    "Has car/truck"
# label variable hv213    "Main floor material"
# label variable hv214    "Main wall material"
# label variable hv215    "Main roof material"
# label variable hv216    "Number of rooms used for sleeping"
# label variable hv217    "Relationship structure"
# label variable hv218    "Line number of head of household"
# label variable hv219    "Sex of head of household"
# label variable hv220    "Age of head of household"
# label variable hv221    "Has telephone (land-line)"
# label variable hv225    "Share toilet with other households"
# label variable hv226    "Type of cooking fuel"
# label variable hv227    "Has mosquito bed net for sleeping"
# label variable hv228    "Children under 5 slept under mosquito bed net last night"
# label variable hv230a   "Place where household members wash their hands"
# label variable hv230b   "Presence of water at hand washing place"
# label variable hv232    "Items present: Soap or detergent"
# label variable hv232b   "Items present: Ash, mud, sand"
# label variable hv232c   "NA - Items present: CS"
# label variable hv232d   "NA - Items present: CS"
# label variable hv232e   "NA - Items present: CS"
# label variable hv232y   "Items present: None"
# label variable hv234    "NA - Result of salt test for iodine (PPM)"
# label variable hv234a   "Result of salt test for iodine"
# label variable hv235    "Location of source for water"
# label variable hv236    "NA - Person fetching water"
# label variable hv237    "Anything done to water to make safe to drink"
# label variable hv237a   "Water usually treated by: boil"
# label variable hv237b   "Water usually treated by: add bleach/chlorine"
# label variable hv237c   "Water usually treated by: strain through a cloth"
# label variable hv237d   "Water usually treated by: use water filter"
# label variable hv237e   "Water usually treated by: solar disinfection"
# label variable hv237f   "Water usually treated by: let it stand and settle"
# label variable hv237g   "Water usually treated by: Alum"
# label variable hv237h   "NA - Water usually treated by: CS"
# label variable hv237i   "NA - Water usually treated by: CS"
# label variable hv237j   "NA - Water usually treated by: CS"
# label variable hv237k   "NA - Water usually treated by: CS"
# label variable hv237x   "Water usually treated by: other"
# label variable hv237z   "Water usually treated by: don't know"
# label variable hv238    "Number of households sharing toilet"
# label variable hv238a   "Location of toilet facility"
# label variable hv239    "NA - Food cooked on stove or open fire"
# label variable hv240    "NA - Household has a chimney, hood or neither"
# label variable hv241    "Food cooked in the house/ separate building/ outdoors"
# label variable hv242    "Household has separate room used as kitchen"
# label variable hv243a   "Has mobile telephone"
# label variable hv243b   "Has watch"
# label variable hv243c   "Has animal-drawn cart"
# label variable hv243d   "Has boat with a motor"
# label variable hv243e   "Has a computer"
# label variable hv244    "Owns land usable for agriculture"
# label variable hv245    "Hectares of agricultural land (1 decimal)"
# label variable hv246    "Owns livestock, herds or farm animals"
# label variable hv246a   "Owns cattle"
# label variable hv246b   "Owns cows/ bulls"
# label variable hv246c   "Owns horses/ donkeys/ mules"
# label variable hv246d   "Owns goats"
# label variable hv246e   "Owns sheep"
# label variable hv246f   "Owns chickens/poultry"
# label variable hv246g   "Owns pigs"
# label variable hv246h   "Owns camel"
# label variable hv246i   "NA - Owns CS"
# label variable hv246j   "NA - Owns CS"
# label variable hv246k   "NA - Owns CS"
# label variable hv247    "Has bank account"
# label variable hv252    "Frequency household members smoke inside the house"
# label variable hv253    "NA - Has dwelling been sprayed against mosquitoes in last 12 months"
# label variable hv253a   "NA - Dwelling sprayed by: government worker/program"
# label variable hv253b   "NA - Dwelling sprayed by: private company"
# label variable hv253c   "NA - Dwelling sprayed by: NGO"
# label variable hv253d   "NA - Dwelling sprayed by: CS"
# label variable hv253e   "NA - Dwelling sprayed by: CS"
# label variable hv253f   "NA - Dwelling sprayed by: CS"
# label variable hv253g   "NA - Dwelling sprayed by: CS"
# label variable hv253h   "NA - Dwelling sprayed by: CS"
# label variable hv253x   "NA - Dwelling sprayed by: other"
# label variable hv253z   "NA - Dwelling sprayed by: don't know"
# label variable hv270    "Wealth index combined"
# label variable hv271    "Wealth index factor score combined (5 decimals)"
# label variable hv270a   "Wealth index for urban/rural"
# label variable hv271a   "Wealth index factor score for urban/rural (5 decimals)"
# label variable hml1     "Number of mosquito bed nets"
# label variable hml1a    "Number of mosquito bed nets with specific information"
# label variable hml2     "Number of children under mosquito bed net previous night"
# label variable shstate  "State"
# label variable chl0     "NA - Number of de-jure children 5-14 for child labor module"
# label variable sh121g   "Has table"
# label variable sh121h   "Has chair"
# label variable sh121i   "Has bed"
# label variable sh121j   "Has sofa"
# label variable sh121k   "Has cupboard"
# label variable sh121l   "Has air conditioner"
# label variable sh121m   "Has electric iron"
# label variable sh121n   "Has generator"
# label variable sh121o   "Has fan"
# label variable sh122h   "Has canoe"
# label variable sh122i   "Has Keke Napep (motorized tricycle)"
# label variable sbelig   "Eligibility for biomarkers"
# label variable sbre     "Household selection for anthropometry revisit"
# label variable hv101    "Relationship to head"
# label variable hv102    "Usual resident"
# label variable hv103    "Slept last night"
# label variable hv104    "Sex of household member"
# label variable hv105    "Age of household members"
# label variable hv106    "Highest educational level attained"
# label variable hv107    "Highest year of education completed"
# label variable hv108    "Education completed in single years"
# label variable hv109    "Educational attainment"
# label variable hv110    "NA - Member still in school"
# label variable hv111    "Mother alive"
# label variable hv112    "Mother's line number"
# label variable hv113    "Father alive"
# label variable hv114    "Father's line number"
# label variable hv115    "Current marital status"
# label variable hv116    "Currently, formerly, never married"
# label variable hv117    "Eligibility for female interview"
# label variable hv118    "Eligibility for male interview"
# label variable hv120    "Children eligibility for height/weight and hemoglobin"
# label variable hv121    "Member attended school during current school year"
# label variable hv122    "Educational level during current school year"
# label variable hv123    "Grade of education during current school year"
# label variable hv124    "Education in single years - current school year"
# label variable hv125    "NA - Member attended school during previous school year"
# label variable hv126    "NA - Educational level during previous school year"
# label variable hv127    "NA - Grade of education during previous school year"
# label variable hv128    "NA - Education in single years - previous school year"
# label variable hv129    "NA - School attendance status"
# label variable hv140    "NA - Member has a birth certificate"
# label variable idxh4    "Index to Household Schedule"
# label variable sh20a    "Birth registered"
# label variable sh20b    "Authority with which birth is registered"
# label variable sh20c    "Birth certificate seen"
# label variable ha0      "Index to Household Schedule"
# label variable ha1      "Woman's age in years"
# label variable ha2      "Woman's weight in kilograms (1 decimal)"
# label variable ha3      "Woman's height in centimeters (1 decimal)"
# label variable ha4      "Height/Age percentile"
# label variable ha5      "Height/Age standard deviation"
# label variable ha6      "Height/Age percent ref. median"
# label variable ha11     "Weight/Height standard deviation (DHS)"
# label variable ha12     "Weight/Height percent ref. median (DHS)"
# label variable ha12a    "Weight/Height percent ref. median (Fog)"
# label variable ha12b    "Weight/Height percent ref. median (WHO)"
# label variable ha13     "Result of measurement - height/weight"
# label variable ha21     "Fieldworker measurer code"
# label variable ha32     "Date of birth (CMC)"
# label variable ha33     "Completeness of HA32 information"
# label variable ha35     "Smoking (cigarettes in last 24 hours)"
# label variable ha40     "Body Mass Index"
# label variable ha41     "Rohrer's index"
# label variable ha50     "Under age 18"
# label variable ha51     "Line number of parent/caretaker"
# label variable ha52     "Read consent statement - hemoglobin"
# label variable ha53     "Hemoglobin level (g/dl - 1 decimal)"
# label variable ha54     "Currently pregnant"
# label variable ha55     "Result of measurement - hemoglobin"
# label variable ha56     "Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)"
# label variable ha57     "Anemia level"
# label variable ha58     "NA - Agrees to referral - anemia"
# label variable ha60     "Marital status"
# label variable ha61     "NA - Read consent statement - HIV"
# label variable ha62     "Bar code for HIV blood sample"
# label variable ha63     "NA - Result of measurement - HIV"
# label variable ha64     "NA - Consent for additional tests"
# label variable ha65     "Result of woman's individual interview"
# label variable ha66     "Woman's highest educational level"
# label variable ha67     "Woman's highest year of education"
# label variable ha68     "Woman's highest educational level (for preliminary and final report)"
# label variable ha69     "NA - HIV weight (6 decimals)"
# label variable ha70     "NA - Interviewer that took blood for HIV testing"
# label variable hc0      "Index to Household Schedule"
# label variable hc1      "Child's age in months"
# label variable hc1a     "Child's age in days"
# label variable hc2      "Child's weight in kilograms (1 decimal)"
# label variable hc3      "Child's height in centimeters (1 decimal)"
# label variable hc4      "Height/Age percentile"
# label variable hc5      "Height/Age standard deviation"
# label variable hc6      "Height/Age percent of ref. median"
# label variable hc7      "Weight/Age percentile"
# label variable hc8      "Weight/Age standard deviation"
# label variable hc9      "Weight/Age percent of ref. median"
# label variable hc10     "Weight/Height percentile"
# label variable hc11     "Weight/Height standard deviation"
# label variable hc12     "Weight/Height percent of ref. median"
# label variable hc13     "Result of measurement - height/weight"
# label variable hc15     "Height: lying or standing"
# label variable hc16     "Day of birth"
# label variable hc17     "Date measured (day)"
# label variable hc18     "Date measured (month)"
# label variable hc19     "Date measured (year)"
# label variable hc20     "Century Day Code (CDC) of measurement"
# label variable hc21     "Fieldworker measurer code"
# label variable hc27     "Sex"
# label variable hc30     "Month of birth"
# label variable hc31     "Year of birth"
# label variable hc32     "Date of birth (CMC)"
# label variable hc32a    "Century Day Code (CDC) of birth"
# label variable hc33     "Completeness of HC32 information"
# label variable hc51     "Line number of parent/caretaker"
# label variable hc52     "Read consent statement - hemoglobin"
# label variable hc53     "Hemoglobin level (g/dl - 1 decimal)"
# label variable hc55     "Result of measurement - hemoglobin"
# label variable hc56     "Hemoglobin level adjusted for altitude (g/dl - 1 decimal)"
# label variable hc57     "Anemia level"
# label variable hc58     "NA - Agrees to referral - anemia"
# label variable hc60     "Mother's line number (woman's questionnaire)"
# label variable hc61     "Mother's highest educational level"
# label variable hc62     "Mother's highest year of education"
# label variable hc63     "Preceding birth interval (months)"
# label variable hc64     "Birth order number"
# label variable hc68     "Mother's highest educational level (for preliminary and final report)"
# label variable hc70     "Height/Age standard deviation (new WHO)"
# label variable hc71     "Weight/Age standard deviation (new WHO)"
# label variable hc72     "Weight/Height standard deviation (new WHO)"
# label variable hc73     "BMI standard deviation (new WHO)"
# label variable hc2a     "Child's weight in kilograms (1 decimal) - first measurement"
# label variable hc3a     "Child's height in centimeters (1 decimal) - first measurement"
# label variable hc15a    "Height: lying or standing - first measurement"
# label variable hc2b     "Child's weight in kilograms (1 decimal) - re-measurement"
# label variable hc3b     "Child's height in centimeters (1 decimal) - re-measurement"
# label variable hc15b    "Height: lying or standing - re-measurement"
# label variable hc35     "Reason for re-measurement"
# label variable sb112    "Blood transfusion in past three months"
# label variable sb112b   "Read consent statement (genotype)"
# label variable sb112f   "Blood sample ID number-Genotype"
# label variable sb113a   "Measurement of genotype RDT"
# label variable sb113b   "Result of genotype RDT"
# label variable sb118a   "Illness or symptoms: extreme weakness"
# label variable sb118b   "Illness or symptoms: heart problems"
# label variable sb118c   "Illness or symptoms: loss of consciousness"
# label variable sb118d   "Illness or symptoms: rapid breathing"
# label variable sb118e   "Illness or symptoms: seizures"
# label variable sb118f   "Illness or symptoms: bleeding"
# label variable sb118g   "Illness or symptoms: jaundice"
# label variable sb118h   "Illness or symptoms: dark urine"
# label variable sb121    "Taken ACT for malaria treatment in the past two weeks"
# label variable sb125    "Accepted medicine"
# label variable hmlidx   "Mosquito Bed Net Designation Number"
# label variable hml3     "Net observed by interviewer"
# label variable hml4     "Months ago net obtained"
# label variable hml5     "NA - Net treated with insecticide when bought"
# label variable hml6     "NA - Net treatment status"
# label variable hml7     "Brand of net"
# label variable hml8     "Net treated since received"
# label variable hml9     "NA - Time since last re-treatment (months)"
# label variable hml10    "Insecticide-Treated Net (ITN)"
# label variable hml11    "Number of persons who slept under this net"
# label variable hml21    "Someone slept under this net last night"
# label variable hmla     "Line number of person who slept in this net"
# label variable hmlb     "Line number of person who slept in this net"
# label variable hmlc     "Line number of person who slept in this net"
# label variable hmld     "Line number of person who slept in this net"
# label variable hmle     "NA - Line number of person who slept in this net"
# label variable hml22    "Obtained net from campaign, antenatal or immunization visit"
# label variable hml23    "Place where net was obtained"
# label variable sh129    "Shown Net"
# label variable sh136a   "Reason not sleeping inside the net"
# label variable hmhidx   "Index to Household Schedule"
# label variable hml12    "Type of Mosquito Bed Net(s) person slept under last night"
# label variable hml13    "Net Designation Number (HMLIDX) for 1st net person slept under last night"
# label variable hml14    "Net Designation Number (HMLIDX) for 2nd net person slept under last night"
# label variable hml15    "Net Designation Number (HMLIDX) for 3rd net person slept under last night"
# label variable hml16    "Corrected age from Individual file"
# label variable hml16a   "Age in months (for children)"
# label variable hml17    "Flag for age from Individual file"
# label variable hml18    "Pregnancy status from Individual file"
# label variable hml19    "Person slept under an ever-treated net"
# label variable hml20    "Person slept under an LLIN net"
# label variable hml30    "Line number of parent/caretaker (for malaria testing)"
# label variable hml31    "Read consent statement for malaria"
# label variable hml32    "Final result of malaria from blood smear test"
# label variable hml32a   "NA - Presence of species: falciparum (Pf)"
# label variable hml32b   "NA - Presence of species: malariae (Pm)"
# label variable hml32c   "NA - Presence of species: ovale (Po)"
# label variable hml32d   "NA - Presence of species: vivax (Pv)"
# label variable hml32e   "NA - Presence of species: CS"
# label variable hml32f   "NA - Presence of species: CS"
# label variable hml32g   "NA - Presence of species: CS"
# label variable hml33    "Result of malaria measurement"
# label variable hml34    "Bar code for blood smear sample"
# label variable hml35    "Result of malaria rapid test"
# label variable hml36    "Fieldworker measurer code for malaria"
# label variable idxdis   "Index to household schedule"
# label variable hdis1    "Wear glasses or contact lenses"
# label variable hdis2    "Have difficulty seeing"
# label variable hdis3    "Wear a hearing aid"
# label variable hdis4    "Have difficulty hearing"
# label variable hdis5    "Have difficulty communicating using usual language"
# label variable hdis6    "Have difficulty remembering or concentrating"
# label variable hdis7    "Have difficulty walking or climbing steps"

# %% [markdown]
# 1. How many children under the age of five were tested for malaria with a blood smear
# test?

# %% [markdown]
# First, let's filter columns we will use:

# %%
dtng1 = dtng[['hv014','hv025','hml32', 'hml33', 'hml35', 'hv025', 'hv023']]

# %%
dtng1
# Out:
#         hv014  hv025 hml32 hml33 hml35  hv025           hv023
# 0           1  urban   NaN   NaN   NaN  urban  nc benue urban
# 1           1  urban   NaN   NaN   NaN  urban  nc benue urban
# 2           1  urban   NaN   NaN   NaN  urban  nc benue urban
# 3           1  urban   NaN   NaN   NaN  urban  nc benue urban
# 4           1  urban   NaN   NaN   NaN  urban  nc benue urban
# ...       ...    ...   ...   ...   ...    ...             ...
# 188005      0  rural   NaN   NaN   NaN  rural    sw oyo rural
# 188006      0  rural   NaN   NaN   NaN  rural    sw oyo rural
# 188007      0  rural   NaN   NaN   NaN  rural    sw oyo rural
# 188008      0  rural   NaN   NaN   NaN  rural    sw oyo rural
# 188009      0  rural   NaN   NaN   NaN  rural    sw oyo rural
#
# [188010 rows x 7 columns]

# %% [markdown]
# In the column of blood smear test there are alot of null values, so we don't know whether the coreesponding children were tested or not. The best solution is to get rid of the corresponding row.

# %%
dtng1n = dtng1.dropna()
dtng1n
# Out:
#         hv014  hv025     hml32     hml33     hml35  hv025           hv023
# 46          1  urban  negative  measured  negative  urban  nc benue urban
# 55          1  urban  negative  measured  negative  urban  nc benue urban
# 63          1  urban  negative  measured  negative  urban  nc benue urban
# 87          1  urban  negative  measured  negative  urban  nc benue urban
# 123         2  urban  negative  measured  negative  urban  nc benue urban
# ...       ...    ...       ...       ...       ...    ...             ...
# 187961      3  rural  negative  measured  negative  rural    sw oyo rural
# 187973      2  rural  negative  measured  negative  rural    sw oyo rural
# 187974      2  rural  negative  measured  negative  rural    sw oyo rural
# 187982      1  rural  negative  measured  negative  rural    sw oyo rural
# 187987      1  rural  negative  measured  negative  rural    sw oyo rural
#
# [8117 rows x 7 columns]

# %%
dtng1n.iloc[:, 2][dtng1n.hv014 < 5].count()
# Out:
# 7778

# %% [markdown]
# Therefore, the number of children under the age of five tested for malaria with a blood smear test are: 7778

# %% [markdown]
# 2. How many children under the age of five were tested for malaria with a rapid test?

# %%
dtng1n.iloc[:, 4][dtng1n.hv014 < 5].count()
# Out:
# 7778

# %% [markdown]
# Also, the number of children under the age of five tested for malaria with a rapid test are: 7778

# %% [markdown]
# 3. How many children tested positive for malaria with a microscopy?

# %% [markdown]
# The children tested for malaria with a microscopy are the one tested with blood smear test. Therefore we calculate it below:

# %%
dtng1n.iloc[:, 2][dtng1n.hml32 == 'positive'].count()
# Out:
# 1935

# %% [markdown]
# Therefore, the number of children tested positive with a microscopy are: 1935

# %% [markdown]
# 4. How many children tested positive for malaria with a rapid test?

# %%
dtng1n.iloc[:, 4][dtng1n.hml35 == 'positive'].count()
# Out:
# 3033

# %% [markdown]
# Therefore, the number of children tested positive with a rapid test are: 3033

# %% [markdown]
# 5. Make a plot showing the number of U5 children that tested positive for malaria by microscopy and the number of U5 children that tested negative for malaria by
# microscopy in urban and rural areas

# %%
ad = dtng1n.iloc[:, 1:3][dtng1n.hv014 < 5]
ad
# Out:
#         hv025     hml32
# 46      urban  negative
# 55      urban  negative
# 63      urban  negative
# 87      urban  negative
# 123     urban  negative
# ...       ...       ...
# 187961  rural  negative
# 187973  rural  negative
# 187974  rural  negative
# 187982  rural  negative
# 187987  rural  negative
#
# [7778 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
x = ad.groupby(['hv025', 'hml32']).size()
x
# Out:
# hv025  hml32
# urban  negative    2830
#        positive     490
# rural  negative    3137
#        positive    1321
# dtype: int64

# %%
x.plot()
# Out:
# <Axes: xlabel='hv025,hml32'>

# %% [markdown]
# We can clearly see that there are less number of children tested positive and high number of children tested negative for malaria in urban areas than in rural areas.

# %% [markdown]
# 6. Make another plot showing the proportion of U5 children that tested positive for malaria by microscopy and the proportion of U5 children that tested negative for malaria by microscopy in urban and rural areas.

# %%
y = x.unstack()
y
# Out:
# hml32  negative  positive
# hv025
# urban      2830       490
# rural      3137      1321

# %%
y1 = y['negative']/y['negative'].sum()
y1
# Out:
# hv025
# urban    0.474275
# rural    0.525725
# Name: negative, dtype: float64

# %%
y2 = y['positive']/y['positive'].sum()
y2
# Out:
# hv025
# urban    0.270569
# rural    0.729431
# Name: positive, dtype: float64

# %%
z1 = pd.DataFrame(y2.values, columns=['positive'], index=['urban', 'rural'])
z1
# Out:
#        positive
# urban  0.270569
# rural  0.729431

# %%
z2 = pd.DataFrame(y1.values, columns=['negative'], index=['urban', 'rural'])
z2
# Out:
#        negative
# urban  0.474275
# rural  0.525725

# %%
z = z1.join(z2).stack()
z
# Out:
# urban  positive    0.270569
#        negative    0.474275
# rural  positive    0.729431
#        negative    0.525725
# dtype: float64

# %%
z.plot()
# Out:
# <Axes: >

# %% [markdown]
# 7. Make a map of the number of children that tested positive for malaria by state

# %%
dmap ={
    'NC Benue Urban':'Benue',
       'NC Benue Rural':'Benue',
       'NC FCT Abuja Urban': 'Abuja',
    'NC FCT Abuja Rural':'Abuja',
      'NC Kogi Urban':'Kogi', 
        'NC Kogi Rural': 'Kogi',
        'NC Kwara Urban':'Kwara',
           'NC Kwara Rural':'Kwara',
           'NC Nasarawa Urban':'Nasarawa',
            'NC Nasarawa Rural':'Nasarawa',
            'NC Niger Urban':'Niger',
            'NC Niger Rural':'Niger',
            'NC Plateau Urban':'Plateau',
'NC Plateau Rural':'Plateau',
'NE Adamawa Urban':'Adamawa',
 'NE Adamawa Rural':'Adamawa',
'NE Bauchi Urban':'Bauchi',
'NE Bauchi Rural':'Bauchi',
'NE Borno Urban':'Borno',
'NE Borno Rural':'Borno',
'NE Gombe Urban':'Gombe',
'NE Gombe Rural':'Gombe',
'NE Taraba Urban':'Taraba',
'NE Taraba Rural':'Taraba',
'NE Yobe Urban':'Yobe',
'NE Yobe Rural':'Yobe',
'NW Jigawa Urban':'Jigawa',
'NW Jigawa Rural': 'Jigawa',
'NW Kaduna Urban':'Kaduna',
'NW Kaduna Rural':'Kaduna',
'NW Kano Urban':'Kano',
'NW Kano Rural':'Kano',
'NW Katsina Urban':'Katsina',
'NW Katsina Rural':'Katsina',
'NW Kebbi Urban':'Kebbi',
'NW Kebbi Rural':'Kebbi',
'NW Sokoto Urban':'Sokoto',
'NW Sokoto Rural':'Sokoto',
'NW Zamfara Urban':'Zamfara',
'NW Zamfara Rural':'Zamfara',
'SE Abia Urban':'Abia',
'SE Abia Rural':'Abia',
'SE Anambra Urban':'Anambra',
'SE Anambra Rural':'Anambra',
'SE Ebonyi Urban':'Ebonyi',
'SE Ebonyi Rural':'Ebonyi',
'SE Enugu Urban':'Enugu',
'SE Enugu Rural':'Enugu',
'SE Imo Urban':'Imo',
'SE Imo Rural':'Imo',
'SS Akwa Ibom Urban':'Akwa Ibom',
 'SS Akwa Ibom Rural':'Akwa Ibom',
 'SS Bayelsa Urban':'Bayelsa',
'SS Bayelsa Rural':'Bayelsa',
 'SS Cross River Urban':'Cross River',
'SS Cross River Rural':'Cross River',
 'SS Delta Urban':'Delta',
'SS Delta Rural':'Delta',
'SS Edo Urban':'Edo',
 'SS Edo Rural':'Edo',
  'SS Rivers Urban':'Rivers',
'SS Rivers Rural':'Rivers',
 'SW Ekiti Urban':'Ekiti',
 'SW Ekiti Rural':'Ekiti',
 'SW Lagos Urban':'Lagos',
 'SW Lagos Rural':'Lagos',
  'SW Ogun Urban':'Ogun',
  'SW Ogun Rural':'Ogun',
 'SW Ondo Urban':'Ondo',
'SW Ondo Rural':'Ondo',
 'SW Osun Urban':'Osun',
 'SW Osun Rural':'Osun',
 'SW Oyo Urban':'Oyo',
 'SW Oyo Rural':'Oyo'}

# %%
p = {x.lower():dmap[x].lower() for x in dmap}

# %%
dtng1n['state'] = dtng1n.hv023.map(p)
# Out:
# /tmp/ipykernel_2960/1070413187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dtng1n['state'] = dtng1n.hv023.map(p)

# %%
dtng1n['state']
# Out:
# 46        benue
# 55        benue
# 63        benue
# 87        benue
# 123       benue
#           ...
# 187961      oyo
# 187973      oyo
# 187974      oyo
# 187982      oyo
# 187987      oyo
# Name: state, Length: 8117, dtype: object

# %%
s = dtng1n.iloc[:, [2,4,7]][dtng1n.hml32 == 'positive'][dtng1n.hml35 == 'positive']
s
# Out:
# /tmp/ipykernel_2960/1083987058.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   s = dtng1n.iloc[:, [2,4,7]][dtng1n.hml32 == 'positive'][dtng1n.hml35 == 'positive']
#            hml32     hml35  state
# 430     positive  positive  benue
# 696     positive  positive  benue
# 914     positive  positive  benue
# 935     positive  positive  benue
# 1191    positive  positive  benue
# ...          ...       ...    ...
# 187590  positive  positive    oyo
# 187613  positive  positive    oyo
# 187614  positive  positive    oyo
# 187683  positive  positive    oyo
# 187908  positive  positive    oyo
#
# [1702 rows x 3 columns]

# %%
d = s.groupby('state').size()
d
# Out:
# state
# abia         16
# abuja        39
# adamawa      35
# akwa ibom    37
# anambra      26
#              ..
# rivers       15
# sokoto       60
# taraba       45
# yobe         27
# zamfara      83
# Length: 37, dtype: int64

# %%
d.plot.barh()
# Out:
# <Axes: ylabel='state'>

# %% [markdown]
# We can see that, unfortunately the state with highest positive malaria is Kano state followed by kebbi state.
